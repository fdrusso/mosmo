# %%
import setpypath

from dataclasses import dataclass, asdict
from typing import Iterable, List, Mapping, Optional

import cobra
import json
import pymongo

# %%
import cobra.test
bigg_core = cobra.test.create_test_model("ecoli")  # iJO1366
print(bigg_core.description)
# Out:
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Escherichia coli str. K-12 substr. MG1655

# %%
for i, m in enumerate(bigg_core.metabolites):
    if m.id.startswith("atp"):
        print(i, m.id)
# Out:
# 306 atp_c

# %%
atp = bigg_core.metabolites[306]
print(atp.annotation)
# Out:
# {'bigg.metabolite': 'atp', 'biocyc': ['META:ATP', 'META:CPD0-1634'], 'chebi': ['CHEBI:10789', 'CHEBI:10841', 'CHEBI:13236', 'CHEBI:15422', 'CHEBI:22249', 'CHEBI:2359', 'CHEBI:237958', 'CHEBI:30616', 'CHEBI:40938', 'CHEBI:57299'], 'kegg.compound': 'C00002', 'kegg.drug': 'D08646', 'metanetx.chemical': 'MNXM3', 'seed.compound': 'cpd00002'}

# %%
bigg_core.reactions[1000].annotation
# Out:
# {'sbo': 'SBO:0000375',
#  'bigg.reaction': 'DHPPDA2',
#  'biocyc': 'META:RIBOFLAVINSYNDEAM-RXN',
#  'ec-code': '3.5.4.26',
#  'kegg.reaction': 'R03459',
#  'metanetx.reaction': 'MNXR97435',
#  'rhea': ['21868', '21869', '21870', '21871']}

# %%
for m in bigg_core.reactions[1000].metabolites:
    print(m.summary())
# Out:
# 25drapp_c
# =========
# Formula: C9H14N5O8P
#
# Producing Reactions
# -------------------
# Percent      Flux Reaction                                                Definition
# 100.00% 0.0004381  GTPCII2 gtp_c + 3.0 h2o_c --> 25drapp_c + for_c + 2.0 h_c + ppi_c
#
# Consuming Reactions
# -------------------
# Percent       Flux Reaction                                  Definition
# 100.00% -0.0004381  DHPPDA2 25drapp_c + h2o_c + h_c --> 5apru_c + nh4_c
# h2o_c
# =====
# Formula: H2O
#
# Producing Reactions
# -------------------
# Percent      Flux   Reaction                                                                      Definition
#   3.82%     4.858     ACONTa                                                      cit_c <=> acon_C_c + h2o_c
#  43.88%     55.82   ATPS4rpp                              adp_c + 4.0 h_p + pi_c <=> atp_c + h2o_c + 3.0 h_c
#   0.00% 0.0004381     CPPPGO                   cpppg3_c + 2.0 h_c + o2_c --> 2.0 co2_c + 2.0 h2o_c + pppg9_c
#  27.63%     35.15 CYTBO3_4pp                          4.0 h_c + 0.5 o2_c + q8h2_c --> h2o_c + 4.0 h_p + q8_c
#   0.68%    0.8589      DHAD1                                                     23dhmb_c --> 3mob_c + h2o_c
#   0.22%    0.2854      DHAD2                                                     23dhmp_c --> 3mop_c + h2o_c
#   0.57%    0.7288      DHDPS                                  aspsa_c + pyr_c --> 23dhdp_c + 2.0 h2o_c + h_c
#   0.26%     0.325     DHORTS                                             dhor__S_c + h2o_c <=> cbasp_c + h_c
#   0.29%    0.3744      DHQTi                                                      3dhq_c --> 3dhsk_c + h2o_c
#   0.00% 0.0002731      DMPPS                              h2mb4p_c + h_c + nadh_c --> dmpp_c + h2o_c + nad_c
#   0.27%    0.3496     ECOAH1                                                    3hbcoa_c <=> b2coa_c + h2o_c
#   0.27%    0.3496     ECOAH2                                                   3hhcoa_c <=> h2o_c + hx2coa_c
#   0.27%    0.3496     ECOAH3                                                   3hocoa_c <=> h2o_c + oc2coa_c
#   0.27%    0.3496     ECOAH4                                                   3hdcoa_c <=> dc2coa_c + h2o_c
#   0.27%    0.3496     ECOAH5                                                  3hddcoa_c <=> dd2coa_c + h2o_c
#   0.21%    0.2732     ECOAH6                                                  3htdcoa_c <=> h2o_c + td2coa_c
#   0.21%    0.2732     ECOAH7                                                 3hhdcoa_c <=> h2o_c + hdd2coa_c
#  11.47%     14.59        ENO                                                         2pg_c <=> h2o_c + pep_c
#   0.01%   0.00767     FESD1s          2.0 4fe4s_c + h2o2_c + 2.0 h_c --> 2.0 3fe4s_c + 2.0 fe3_c + 2.0 h2o_c
#   0.17%    0.2172     G5SADs                                             glu5sa_c --> 1pyr5c_c + h2o_c + h_c
#   0.86%     1.096     GHMT2r                                    ser__L_c + thf_c <=> gly_c + h2o_c + mlthf_c
#   6.60%     8.401      GLUDy                     glu__L_c + h2o_c + nadp_c <=> akg_c + h_c + nadph_c + nh4_c
#   0.07%   0.09307      IGPDH                                                     eig3p_c --> h2o_c + imacp_c
#   0.04%   0.05584       IGPS                                      2cpr5p_c + h_c --> 3ig3p_c + co2_c + h2o_c
#   0.42%    0.5332       IMPC                                                      h2o_c + imp_c <=> fprica_c
#   0.00%  0.002074      IPDPS                              h2mb4p_c + h_c + nadh_c --> h2o_c + ipdp_c + nad_c
#   0.35%    0.4426     IPPMIb                                                    2ippm_c + h2o_c <=> 3c3hmp_c
#   0.00%  0.002347   MECDPDH5                  2mecdp_c + 2.0 flxr_c + h_c --> 2.0 flxso_c + h2mb4p_c + h2o_c
#   0.00% 0.0001198      MOCOS                  2.0 h_c + mobd_c + mptamp_c --> amp_c + cu2_c + h2o_c + moco_c
#   0.00% 1.965E-06   OGMEACPD                                                 hgmeACP_c --> egmeACP_c + h2o_c
#   0.00% 1.965E-06   OPMEACPD                                                 hpmeACP_c --> epmeACP_c + h2o_c
#   0.00% 0.0004381     PDX5PS dxyl5p_c + nad_c + phthr_c --> co2_c + 2.0 h2o_c + h_c + nadh_c + pdx5p_c + ...
#   0.00%  0.003505     PPBNGS                                        2.0 5aop_c --> 2.0 h2o_c + h_c + ppbng_c
#   0.14%     0.182      PPNDH                                        h_c + pphn_c --> co2_c + h2o_c + phpyr_c
#   0.00%  0.004476      QULNS                                   dhap_c + iasp_c --> 2.0 h2o_c + pi_c + quln_c
#   0.00%  0.001753      RBFSa                                  4r5au_c + db4p_c --> dmlz_c + 2.0 h2o_c + pi_c
#   0.02%    0.0257    RNTR1c2                   atp_c + 2.0 flxr_c + 2.0 h_c --> datp_c + 2.0 flxso_c + h2o_c
#   0.02%   0.02654    RNTR2c2                   2.0 flxr_c + gtp_c + 2.0 h_c --> dgtp_c + 2.0 flxso_c + h2o_c
#   0.02%   0.02654    RNTR3c2                   ctp_c + 2.0 flxr_c + 2.0 h_c --> dctp_c + 2.0 flxso_c + h2o_c
#   0.02%    0.0257    RNTR4c2                   2.0 flxr_c + 2.0 h_c + utp_c --> dutp_c + 2.0 flxso_c + h2o_c
#   0.57%    0.7305       SULR                5.0 h_c + 3.0 nadph_c + so3_c --> 3.0 h2o_c + h2s_c + 3.0 nadp_c
#   0.00% 0.0004381    THZPSN3 atp_c + dhgly_c + dxyl5p_c + h_c + iscssh_c + nadph_c --> 4mpetz_c + amp_c +...
#   0.04%   0.05584     TRPAS2                                   h2o_c + trp__L_c <=> indole_c + nh4_c + pyr_c
#   0.00% 0.0004381      UPP3S                                                     hmbil_c --> h2o_c + uppg3_c
#
# Consuming Reactions
# -------------------
# Percent       Flux                       Reaction                                                                      Definition
#   0.00%  -0.000221                          5DOAN                                             dad_5_c + h2o_c --> 5drib_c + ade_c
#   0.23%    -0.2906                          ACODA                                                acorn_c + h2o_c --> ac_c + orn_c
#   3.82%     -4.858                         ACONTb                                                     acon_C_c + h2o_c <=> icit_c
#   0.00% -0.0004401                        AHCYSNS                                             ahcys_c + h2o_c --> ade_c + rhcys_c
#   0.00% -0.0002191                         AMPMS2                air_c + h2o_c + nad_c --> 4ampm_c + 2.0 for_c + 3.0 h_c + nadh_c
#   2.48%      -3.15                           ATPM                                            atp_c + h2o_c --> adp_c + h_c + pi_c
#  37.53%     -47.74 BIOMASS_Ec_iJO1366_core_53p95M 0.000223 10fthf_c + 2.6e-05 2fe2s_c + 0.000223 2ohph_c + 0.00026 4fe4s_c + 0...
#   0.19%    -0.2435                           BPNT                                                  h2o_c + pap_c --> amp_c + pi_c
#   0.00% -0.0002397                          CPMPS                                                gtp_c + h2o_c --> cpmp_c + ppi_c
#   3.82%     -4.858                             CS                                 accoa_c + h2o_c + oaa_c --> cit_c + coa_c + h_c
#   0.12%    -0.1577                          CTPS2  atp_c + gln__L_c + h2o_c + utp_c --> adp_c + ctp_c + glu__L_c + 2.0 h_c + pi_c
#   0.12%    -0.1512                          CYSTL                                 cyst__L_c + h2o_c --> hcys__L_c + nh4_c + pyr_c
#   0.29%    -0.3744                           DDPA                                       e4p_c + h2o_c + pep_c --> 2dda7p_c + pi_c
#   0.00% -0.0004381                        DHPPDA2                                     25drapp_c + h2o_c + h_c --> 5apru_c + nh4_c
#   0.00% -0.0006572                         DNMPPA                                              dhpmp_c + h2o_c --> dhnpt_c + pi_c
#   0.00% -0.0006572                         DNTPPA                                        ahdt_c + h2o_c --> dhpmp_c + h_c + ppi_c
#   0.02%    -0.0257                         DUTPDP                                         dutp_c + h2o_c --> dump_c + h_c + ppi_c
#   0.00% -0.0002191                           E4PD                             e4p_c + h2o_c + nad_c <=> 4per_c + 2.0 h_c + nadh_c
#   0.06%   -0.07645                      FACOAE120                                      ddcacoa_c + h2o_c --> coa_c + ddca_c + h_c
#   0.10%    -0.1254                      FACOAE160                                       h2o_c + pmtcoa_c --> coa_c + h_c + hdca_c
#   0.12%    -0.1478                      FACOAE161                                       h2o_c + hdcoa_c --> coa_c + h_c + hdcea_c
#   3.79%     -4.826                            FUM                                                      fum_c + h2o_c <=> mal__L_c
#   0.00% -0.0006572                         GCALDD                         gcald_c + h2o_c + nad_c --> glyclt_c + 2.0 h_c + nadh_c
#   0.35%    -0.4403                         GLUPRT                         gln__L_c + h2o_c + prpp_c --> glu__L_c + ppi_c + pram_c
#   0.19%    -0.2394                          GMPS2 atp_c + gln__L_c + h2o_c + xmp_c --> amp_c + glu__L_c + gmp_c + 2.0 h_c + ppi_c
#   0.00% -0.0006572                          GTPCI                                          gtp_c + h2o_c --> ahdt_c + for_c + h_c
#   0.00%  -0.001314                        GTPCII2                       gtp_c + 3.0 h2o_c --> 25drapp_c + for_c + 2.0 h_c + ppi_c
#  35.86%     -45.62                         H2Otpp                                                                 h2o_p <=> h2o_c
#   0.41%    -0.5166                          HCO3E                                                  co2_c + h2o_c <=> h_c + hco3_c
#   0.07%   -0.09307                          HISTD                 h2o_c + histd_c + 2.0 nad_c --> 3.0 h_c + his__L_c + 2.0 nadh_c
#   0.07%   -0.09307                          HISTP                                               h2o_c + hisp_c --> histd_c + pi_c
#   0.00% -0.0004381                           HMBS                                     h2o_c + 4.0 ppbng_c --> hmbil_c + 4.0 nh4_c
#   0.19%    -0.2394                           IMPD                                  h2o_c + imp_c + nad_c --> h_c + nadh_c + xmp_c
#   0.35%    -0.4426                         IPPMIa                                                    3c2hmp_c <=> 2ippm_c + h2o_c
#   0.35%    -0.4426                           IPPS                             3mob_c + accoa_c + h2o_c --> 3c3hmp_c + coa_c + h_c
#   0.02%   -0.01911                     K2L4Aabcpp              atp_c + h2o_c + kdo2lipid4_c --> adp_c + h_c + kdo2lipid4_p + pi_c
#   0.02%   -0.01911                    K2L4Aabctex              atp_c + h2o_c + kdo2lipid4_p --> adp_c + h_c + kdo2lipid4_e + pi_c
#   0.03%   -0.03823                          KDOPP                                                h2o_c + kdo8p_c --> kdo_c + pi_c
#   0.03%   -0.03823                          KDOPS                                      ara5p_c + h2o_c + pep_c --> kdo8p_c + pi_c
#   0.00% -0.0006572                           MALS                              accoa_c + glx_c + h2o_c --> coa_c + h_c + mal__L_c
#   0.00% -0.0008822                          METAT                              atp_c + h2o_c + met__L_c --> amet_c + pi_c + ppi_c
#   0.00% -0.0001267                      MOBDabcpp                          atp_c + h2o_c + mobd_p --> adp_c + h_c + mobd_c + pi_c
#   0.00% -0.0005658                          MOHMT                                     3mob_c + h2o_c + mlthf_c --> 2dhp_c + thf_c
#   0.76%    -0.9713                          MTHFC                                              h2o_c + methf_c <=> 10fthf_c + h_c
#   0.00% -0.0004401                       MTHTHFSs                                                   h2o_c + mdhdhf_c --> mththf_c
#   0.04%   -0.04514                     PE160abcpp                        atp_c + h2o_c + pe160_c --> adp_c + h_c + pe160_p + pi_c
#   0.02%   -0.02069                     PE161abcpp                        atp_c + h2o_c + pe161_c --> adp_c + h_c + pe161_p + pi_c
#   3.21%     -4.082                            PGL                                                 6pgl_c + h2o_c --> 6pgc_c + h_c
#   0.00% -0.0004381                         PMDPHT                                             5aprbu_c + h2o_c --> 4r5au_c + pi_c
#   0.00% -1.965E-06                        PMEACPE                                          h2o_c + pmeACP_c --> meoh_c + pimACP_c
#   2.29%     -2.907                            PPC                                    co2_c + h2o_c + pep_c --> h_c + oaa_c + pi_c
#   0.07%   -0.09307                         PRAMPC                                                     h2o_c + prbamp_c --> prfp_c
#   0.07%   -0.09307                         PRATPP                                     h2o_c + prbatp_c --> h_c + ppi_c + prbamp_c
#   0.35%    -0.4403                          PRFGS   atp_c + fgam_c + gln__L_c + h2o_c --> adp_c + fpram_c + glu__L_c + h_c + pi_c
#   1.33%     -1.688                          PSP_L                                           h2o_c + pser__L_c --> pi_c + ser__L_c
#   0.19%    -0.2435                          SADT2                  atp_c + gtp_c + h2o_c + so4_c --> aps_c + gdp_c + pi_c + ppi_c
#   0.29%    -0.3644                          SDPDS                                        h2o_c + sl26da_c --> 26dap_LL_c + succ_c
#   0.29%    -0.3644                          THDPS                                  h2o_c + succoa_c + thdp_c --> coa_c + sl2a6o_c
#   0.42%    -0.5346                           THRS                                              h2o_c + phom_c --> pi_c + thr__L_c
#   0.02%    -0.0273                         UDCPDP                                       h2o_c + udcpdp_c --> h_c + pi_c + udcpp_c
#   0.03%   -0.03823                         UHGADA                                              h2o_c + u3aga_c --> ac_c + u3hga_c
#   0.02%   -0.01911                           USHD                                  h2o_c + u23ga_c --> 2.0 h_c + lipidX_c + ump_c
# h_c
# ===
# Formula: H
#
# Producing Reactions
# -------------------
# Percent      Flux                       Reaction                                                                      Definition
#   0.03%   0.07646                         ACCOAC                      accoa_c + atp_c + hco3_c --> adp_c + h_c + malcoa_c + pi_c
#   0.10%    0.2906                           ACGS                                    accoa_c + glu__L_c --> acglu_c + coa_c + h_c
#   0.00% 0.0006572                           ADCL                                               4adcho_c --> 4abz_c + h_c + pyr_c
#   0.00% 0.0006611                          ADNK1                                           adn_c + atp_c --> adp_c + amp_c + h_c
#   0.08%    0.2435                           ADSK                                          aps_c + atp_c --> adp_c + h_c + paps_c
#   0.20%    0.5875                           ADSS                   asp__L_c + gtp_c + imp_c --> dcamp_c + gdp_c + 2.0 h_c + pi_c
#   0.15%    0.4401                          AIRC2                         air_c + atp_c + hco3_c --> 5caiz_c + adp_c + h_c + pi_c
#   0.01%    0.0273                        ALAALAr                          2.0 ala__D_c + atp_c <=> adp_c + alaala_c + h_c + pi_c
#   0.00% 0.0006572                         AMPMS2                air_c + h2o_c + nad_c --> 4ampm_c + 2.0 for_c + 3.0 h_c + nadh_c
#   0.02%   0.05584                            ANS                           chor_c + gln__L_c --> anth_c + glu__L_c + h_c + pyr_c
#   0.10%    0.2906                          ARGSS                 asp__L_c + atp_c + citr__L_c --> amp_c + argsuc_c + h_c + ppi_c
#   0.08%    0.2368                          ASNS2                     asp__L_c + atp_c + nh4_c --> amp_c + asn__L_c + h_c + ppi_c
#   0.11%     0.325                          ASPCT                                       asp__L_c + cbp_c --> cbasp_c + h_c + pi_c
#   0.00%  0.002238                          ASPO6                                       asp__L_c + o2_c --> h2o2_c + h_c + iasp_c
#   1.10%      3.15                           ATPM                                            atp_c + h2o_c --> adp_c + h_c + pi_c
#  58.21%     167.4                       ATPS4rpp                              adp_c + 4.0 h_p + pi_c <=> atp_c + h2o_c + 3.0 h_c
#  18.43%        53 BIOMASS_Ec_iJO1366_core_53p95M 0.000223 10fthf_c + 2.6e-05 2fe2s_c + 0.000223 2ohph_c + 0.00026 4fe4s_c + 0...
#   0.00% 1.965E-06                           BTS5        2fe2s_c + amet_c + dtbt_c --> 2fe1s_c + btn_c + dad_5_c + h_c + met__L_c
#   0.43%     1.231                          CBMKr                               atp_c + co2_c + nh4_c <=> adp_c + cbp_c + 2.0 h_c
#   0.00%  0.002347                         CDPMEK                                     4c2me_c + atp_c --> 2p4c2me_c + adp_c + h_c
#   1.69%     4.858                             CS                                 accoa_c + h2o_c + oaa_c --> cit_c + coa_c + h_c
#   0.11%    0.3154                          CTPS2  atp_c + gln__L_c + h2o_c + utp_c --> adp_c + ctp_c + glu__L_c + 2.0 h_c + pi_c
#   0.08%    0.2435                           CYSS                                       acser_c + h2s_c --> ac_c + cys__L_c + h_c
#   0.00%   0.01365                       DALAt2pp                                               ala__D_p + h_p --> ala__D_c + h_c
#   0.00% 0.0008763                          DB4PS                                              ru5p__D_c --> db4p_c + for_c + h_c
#   0.00% 5.894E-06                           DBTS                      atp_c + co2_c + dann_c --> adp_c + dtbt_c + 3.0 h_c + pi_c
#   0.13%    0.3644                          DHDPS                                  aspsa_c + pyr_c --> 23dhdp_c + 2.0 h2o_c + h_c
#   0.00% 0.0006572                           DHFS                        atp_c + dhpt_c + glu__L_c --> adp_c + dhf_c + h_c + pi_c
#   0.00% 0.0006572                         DNTPPA                                        ahdt_c + h2o_c --> dhpmp_c + h_c + ppi_c
#   0.00% 0.0005658                         DPCOAK                                         atp_c + dpcoa_c --> adp_c + coa_c + h_c
#   0.01%    0.0257                         DUTPDP                                         dutp_c + h2o_c --> dump_c + h_c + ppi_c
#   0.00% 0.0004381                           E4PD                             e4p_c + h2o_c + nad_c <=> 4per_c + 2.0 h_c + nadh_c
#   0.03%   0.07645                      FACOAE120                                      ddcacoa_c + h2o_c --> coa_c + ddca_c + h_c
#   0.04%    0.1254                      FACOAE160                                       h2o_c + pmtcoa_c --> coa_c + h_c + hdca_c
#   0.05%    0.1478                      FACOAE161                                       h2o_c + hdcoa_c --> coa_c + h_c + hdcea_c
#   0.00% 0.0004381                           FCLT                                            fe2_c + ppp9_c --> 2.0 h_c + pheme_c
#   0.03%   0.09282                         G1PACT                                   accoa_c + gam1p_c --> acgam1p_c + coa_c + h_c
#   0.08%    0.2172                         G5SADs                                             glu5sa_c --> 1pyr5c_c + h2o_c + h_c
#   1.42%     4.082                        G6PDH2r                                       g6p_c + nadp_c <=> 6pgl_c + h_c + nadph_c
#   5.66%     16.27                           GAPD                                 g3p_c + nad_c + pi_c <=> 13dpg_c + h_c + nadh_c
#   0.15%    0.4379                          GARFT                                       10fthf_c + gar_c <=> fgam_c + h_c + thf_c
#   0.00%   0.00241                           GART                           atp_c + for_c + gar_c --> adp_c + fgam_c + h_c + pi_c
#   0.00%  0.001314                         GCALDD                         gcald_c + h2o_c + nad_c --> glyclt_c + 2.0 h_c + nadh_c
#   0.62%     1.779                           GLNS                      atp_c + glu__L_c + nh4_c --> adp_c + gln__L_c + h_c + pi_c
#   0.17%    0.4788                          GMPS2 atp_c + gln__L_c + h2o_c + xmp_c --> amp_c + glu__L_c + gmp_c + 2.0 h_c + ppi_c
#   0.00% 0.0006572                          GTPCI                                          gtp_c + h2o_c --> ahdt_c + for_c + h_c
#   0.00% 0.0008763                        GTPCII2                       gtp_c + 3.0 h2o_c --> 25drapp_c + for_c + 2.0 h_c + ppi_c
#   0.18%    0.5166                          HCO3E                                                  co2_c + h2o_c <=> h_c + hco3_c
#   0.10%    0.2792                          HISTD                 h2o_c + histd_c + 2.0 nad_c --> 3.0 h_c + his__L_c + 2.0 nadh_c
#   0.00% 0.0006572                          HPPK2                                   6hmhpt_c + atp_c --> 6hmhptpp_c + amp_c + h_c
#   0.19%    0.5346                            HSK                                       atp_c + hom__L_c --> adp_c + h_c + phom_c
#   0.00% 7.859E-06                        I2FE2SR                 2fe1s_c + iscssh_c + iscu_c --> 4.0 h_c + iscs_c + iscu_2fe2s_c
#   0.00%  0.001686                        I2FE2SS fadh2_c + 2.0 fe2_c + 2.0 iscssh_c + iscu_c --> fad_c + 6.0 h_c + 2.0 iscs_c...
#   0.00%  0.001533                       I2FE2SS2 fadh2_c + 2.0 fe2_c + 2.0 iscssh_c + iscu_2fe2s_c --> fad_c + 6.0 h_c + 2.0 ...
#   0.03%   0.09307                          IG3PS                        gln__L_c + prlp_c --> aicar_c + eig3p_c + glu__L_c + h_c
#   0.08%    0.2394                           IMPD                                  h2o_c + imp_c + nad_c --> h_c + nadh_c + xmp_c
#   0.15%    0.4426                           IPMD                                    3c2hmp_c + nad_c --> 3c4mop_c + h_c + nadh_c
#   0.15%    0.4426                           IPPS                             3mob_c + accoa_c + h2o_c --> 3c3hmp_c + coa_c + h_c
#   0.01%   0.01911                     K2L4Aabcpp              atp_c + h2o_c + kdo2lipid4_c --> adp_c + h_c + kdo2lipid4_p + pi_c
#   0.01%   0.01911                    K2L4Aabctex              atp_c + h2o_c + kdo2lipid4_p --> adp_c + h_c + kdo2lipid4_e + pi_c
#   0.07%    0.1918                          Kt2pp                                                         h_p + k_p --> h_c + k_c
#   0.01%   0.01911                         LPADSS                                 lipidX_c + u23ga_c --> h_c + lipidAds_c + udp_c
#   0.00% 0.0006572                           MALS                              accoa_c + glx_c + h2o_c --> coa_c + h_c + mal__L_c
#   1.68%     4.825                            MDH                                       mal__L_c + nad_c <=> h_c + nadh_c + oaa_c
#   0.05%    0.1516                           METS                                  5mthf_c + hcys__L_c --> h_c + met__L_c + thf_c
#   0.01%   0.01911                           MOAT                                 ckdo_c + lipidA_c --> cmp_c + h_c + kdolipid4_c
#   0.01%   0.01911                          MOAT2                             ckdo_c + kdolipid4_c --> cmp_c + h_c + kdo2lipid4_c
#   0.00% 0.0001267                      MOBDabcpp                          atp_c + h2o_c + mobd_p --> adp_c + h_c + mobd_c + pi_c
#   0.01%    0.0273                           MPTG                         2.0 uaagmda_c --> 2.0 h_c + murein5p5p_p + 2.0 udcpdp_c
#   0.00%  0.001198                           MPTS             cpmp_c + cu2_c + 2.0 moadcosh_c --> 5.0 h_c + 2.0 moadcoo_c + mpt_c
#   0.34%    0.9713                          MTHFC                                              h2o_c + methf_c <=> 10fthf_c + h_c
#   0.00% 0.0004391                           NADK                                          atp_c + nad_c --> adp_c + h_c + nadp_c
#   0.00%  0.002238                          NADS1                          atp_c + dnad_c + nh4_c --> amp_c + h_c + nad_c + ppi_c
#   0.10%    0.2906                           OCBT                                        cbp_c + orn_c <=> citr__L_c + h_c + pi_c
#   0.00% 0.0005658                          PANTS                 ala_B_c + atp_c + pant__R_c --> amp_c + h_c + pnto__R_c + ppi_c
#   0.17%     0.487                          PAPSR                          paps_c + trdrd_c --> 2.0 h_c + pap_c + so3_c + trdox_c
#   0.00% 0.0002191                        PDX5PO2                                     nad_c + pdx5p_c --> h_c + nadh_c + pydx5p_c
#   0.00% 0.0002191                         PDX5PS dxyl5p_c + nad_c + phthr_c --> co2_c + 2.0 h2o_c + h_c + nadh_c + pdx5p_c + ...
#   0.02%   0.04514                     PE160abcpp                        atp_c + h2o_c + pe160_c --> adp_c + h_c + pe160_p + pi_c
#   0.01%   0.02069                     PE161abcpp                        atp_c + h2o_c + pe161_c --> adp_c + h_c + pe161_p + pi_c
#   0.00% 0.0002191                           PERD                                        4per_c + nad_c <=> h_c + nadh_c + ohpb_c
#   2.00%     5.752                            PFK                                           atp_c + f6p_c --> adp_c + fdp_c + h_c
#   0.41%     1.167                          PFK_3                                         atp_c + s7p_c --> adp_c + h_c + s17bp_c
#   0.59%     1.688                           PGCD                                         3pg_c + nad_c --> 3php_c + h_c + nadh_c
#   1.42%     4.082                            PGL                                                 6pgl_c + h2o_c --> 6pgc_c + h_c
#   0.33%    0.9476                        PIt2rpp                                                       h_p + pi_p <=> h_c + pi_c
#   0.00% 0.0005658                           PNTK                                     atp_c + pnto__R_c --> 4ppan_c + adp_c + h_c
#   0.04%    0.1068                           POR5              coa_c + 2.0 flxso_c + pyr_c <=> accoa_c + co2_c + 2.0 flxr_c + h_c
#   0.00%  0.001753                         PPBNGS                                        2.0 5aop_c --> 2.0 h2o_c + h_c + ppbng_c
#   1.01%     2.907                            PPC                                    co2_c + h2o_c + pep_c --> h_c + oaa_c + pi_c
#   0.00% 0.0005658                         PPNCL2                   4ppan_c + ctp_c + cys__L_c --> 4ppcys_c + cmp_c + h_c + ppi_c
#   0.15%    0.4403                         PRAGSr                           atp_c + gly_c + pram_c <=> adp_c + gar_c + h_c + pi_c
#   0.31%    0.8807                          PRAIS                              atp_c + fpram_c --> adp_c + air_c + 2.0 h_c + pi_c
#   0.15%    0.4401                        PRASCSi                    5aizc_c + asp__L_c + atp_c --> 25aics_c + adp_c + h_c + pi_c
#   0.03%   0.09307                         PRATPP                                     h2o_c + prbatp_c --> h_c + ppi_c + prbamp_c
#   0.15%    0.4403                          PRFGS   atp_c + fgam_c + gln__L_c + h2o_c --> adp_c + fpram_c + glu__L_c + h_c + pi_c
#   0.32%    0.9164                          PRPPS                                          atp_c + r5p_c <=> amp_c + h_c + prpp_c
#   0.02%   0.06269                        PSSA160                                cdpdhdecg_c + ser__L_c --> cmp_c + h_c + ps160_c
#   0.03%   0.07389                        PSSA161                              cdpdhdec9eg_c + ser__L_c --> cmp_c + h_c + ps161_c
#   0.00% 0.0002191                           RBFK                                        atp_c + ribflv_c --> adp_c + fmn_c + h_c
#   0.00% 0.0002191                         SHCHD2                                         dscl_c + nad_c --> h_c + nadh_c + scl_c
#   0.00% 0.0006572                          SHCHF                                             fe2_c + scl_c --> 3.0 h_c + sheme_c
#   0.13%    0.3744                           SHKK                                         atp_c + skm_c --> adp_c + h_c + skm5p_c
#   0.05%    0.1512                          SHSL1                                cys__L_c + suchms_c --> cyst__L_c + h_c + succ_c
#   0.09%    0.2478                        SO4t2pp                                                     h_p + so4_p --> h_c + so4_c
#   0.01%   0.01911                           TDSK                                   atp_c + lipidAds_c --> adp_c + h_c + lipidA_c
#   0.00% 0.0002191                           TYRL amet_c + nadph_c + tyr__L_c --> 4crsol_c + dad_5_c + dhgly_c + h_c + met__L_...
#   0.01%   0.03823                        U23GAAT                                  3hmrsACP_c + u3hga_c --> ACP_c + h_c + u23ga_c
#   0.01%    0.0273                         UAAGDS                    26dap__M_c + atp_c + uamag_c --> adp_c + h_c + pi_c + ugmd_c
#   0.01%    0.0273                         UAGPT3                                 uacgam_c + uagmda_c --> h_c + uaagmda_c + udp_c
#   0.01%    0.0273                         UAMAGS                      atp_c + glu__D_c + uama_c --> adp_c + h_c + pi_c + uamag_c
#   0.01%    0.0273                          UAMAS                       ala__L_c + atp_c + uamr_c --> adp_c + h_c + pi_c + uama_c
#   0.01%    0.0273                         UDCPDP                                       h2o_c + udcpdp_c --> h_c + pi_c + udcpp_c
#   0.01%    0.0273                         UGMDDS                      alaala_c + atp_c + ugmd_c --> adp_c + h_c + pi_c + ugmda_c
#   0.00% 0.0002191                         UPP3MT                             2.0 amet_c + uppg3_c --> 2.0 ahcys_c + dscl_c + h_c
#   0.01%   0.03823                           USHD                                  h2o_c + u23ga_c --> 2.0 h_c + lipidX_c + ump_c
#
# Consuming Reactions
# -------------------
# Percent       Flux   Reaction                                                                      Definition
#   0.03%   -0.07645    3OAR140                              3omrsACP_c + h_c + nadph_c <=> 3hmrsACP_c + nadp_c
#   0.03%   -0.07645    3OAS140                       ddcaACP_c + h_c + malACP_c --> 3omrsACP_c + ACP_c + co2_c
#   0.10%    -0.2854      ACHBS                                      2obut_c + h_c + pyr_c --> 2ahbut_c + co2_c
#   0.30%    -0.8589       ACLS                                           h_c + 2.0 pyr_c --> alac__S_c + co2_c
#   0.10%    -0.2906       AGPR                            acg5sa_c + nadp_c + pi_c <=> acg5p_c + h_c + nadph_c
#   0.00% -0.0004381     APRAUR                                   5apru_c + h_c + nadph_c --> 5aprbu_c + nadp_c
#   0.37%      -1.05       ASAD                             aspsa_c + nadp_c + pi_c <=> 4pasp_c + h_c + nadph_c
#   0.00% -0.0005658     ASP1DC                                              asp__L_c + h_c --> ala_B_c + co2_c
#   0.00% -0.0001198    BMOGDS1                                   bmoco_c + gtp_c + h_c --> bmoco1gdp_c + ppi_c
#   0.00% -0.0001198    BMOGDS2                                bmoco1gdp_c + gtp_c + h_c --> bmocogdp_c + ppi_c
#   0.00%  -0.002557   CLt3_2pp                                               2.0 cl_p + h_c --> 2.0 cl_c + h_p
#   0.00% -0.0004381     CPPPGO                   cpppg3_c + 2.0 h_c + o2_c --> 2.0 co2_c + 2.0 h2o_c + pppg9_c
#  48.88%     -140.6 CYTBO3_4pp                          4.0 h_c + 0.5 o2_c + q8h2_c --> h2o_c + 4.0 h_p + q8_c
#   0.12%    -0.3371      DAPDC                                           26dap__M_c + h_c --> co2_c + lys__L_c
#   0.02%   -0.06269   DASYN160                                   ctp_c + h_c + pa160_c --> cdpdhdecg_c + ppi_c
#   0.03%   -0.07389   DASYN161                                 ctp_c + h_c + pa161_c --> cdpdhdec9eg_c + ppi_c
#   0.13%    -0.3644     DHDPRy                                    23dhdp_c + h_c + nadph_c --> nadp_c + thdp_c
#   0.01%   -0.02636       DHFR                                        dhf_c + h_c + nadph_c <=> nadp_c + thf_c
#   0.11%     -0.325     DHORTS                                             dhor__S_c + h2o_c <=> cbasp_c + h_c
#   0.00% -0.0004381    DHPPDA2                                     25drapp_c + h2o_c + h_c --> 5apru_c + nh4_c
#   0.00% -0.0002731      DMPPS                              h2mb4p_c + h_c + nadh_c --> dmpp_c + h2o_c + nad_c
#   0.00% -0.0005658        DPR                                   2dhp_c + h_c + nadph_c --> nadp_c + pant__R_c
#   0.00%  -0.002347     DXPRIi                                   dxyl5p_c + h_c + nadph_c --> 2me4p_c + nadp_c
#   0.00%  -0.002785       DXPS                                        g3p_c + h_c + pyr_c --> co2_c + dxyl5p_c
#   0.00% -1.965E-06   EGMEACPR                                 egmeACP_c + h_c + nadph_c --> gmeACP_c + nadp_c
#   0.00% -1.965E-06   EPMEACPR                                 epmeACP_c + h_c + nadph_c --> nadp_c + pmeACP_c
#   0.75%     -2.147      FADRx                                        fad_c + h_c + nadh_c --> fadh2_c + nad_c
#   0.00%   -0.00767     FESD1s          2.0 4fe4s_c + h2o2_c + 2.0 h_c --> 2.0 3fe4s_c + 2.0 fe3_c + 2.0 h2o_c
#   0.00% -0.0002191      FMNAT                                           atp_c + fmn_c + h_c --> fad_c + ppi_c
#   0.05%    -0.1366      G3PD2                                    glyc3p_c + nadp_c <=> dhap_c + h_c + nadph_c
#   0.08%    -0.2172       G5SD                            glu5p_c + h_c + nadph_c --> glu5sa_c + nadp_c + pi_c
#   2.92%     -8.401      GLUDy                     glu__L_c + h2o_c + nadp_c <=> akg_c + h_c + nadph_c + nh4_c
#   0.00%  -0.003505     GLUTRR                     glutrna_c + h_c + nadph_c --> glu1sa_c + nadp_c + trnaglu_c
#   0.12%    -0.3496      HACD1                                     aacoa_c + h_c + nadh_c <=> 3hbcoa_c + nad_c
#   0.12%    -0.3496      HACD2                                    3ohcoa_c + h_c + nadh_c <=> 3hhcoa_c + nad_c
#   0.12%    -0.3496      HACD3                                    3oocoa_c + h_c + nadh_c <=> 3hocoa_c + nad_c
#   0.12%    -0.3496      HACD4                                    3odcoa_c + h_c + nadh_c <=> 3hdcoa_c + nad_c
#   0.12%    -0.3496      HACD5                                  3oddcoa_c + h_c + nadh_c <=> 3hddcoa_c + nad_c
#   0.09%    -0.2732      HACD6                                  3otdcoa_c + h_c + nadh_c <=> 3htdcoa_c + nad_c
#   0.09%    -0.2732      HACD7                                  3ohdcoa_c + h_c + nadh_c <=> 3hhdcoa_c + nad_c
#   0.24%    -0.6858       HSDy                                   hom__L_c + nadp_c <=> aspsa_c + h_c + nadph_c
#   0.00%   -0.00011    I2FE2ST                                     4.0 h_c + iscu_2fe2s_c --> 2fe2s_c + iscu_c
#   0.00% -0.0005108    I4FE4SR                      fadh2_c + 2.0 h_c + iscu_2fe2s2_c --> fad_c + iscu_4fe4s_c
#   0.00%  -0.001022    I4FE4ST                                     4.0 h_c + iscu_4fe4s_c --> 4fe4s_c + iscu_c
#   0.02%   -0.05584       IGPS                                      2cpr5p_c + h_c --> 3ig3p_c + co2_c + h2o_c
#   0.00%  -0.002074      IPDPS                              h2mb4p_c + h_c + nadh_c --> h2o_c + ipdp_c + nad_c
#   0.30%    -0.8589      KARA1                                 23dhmb_c + nadp_c <=> alac__S_c + h_c + nadph_c
#   0.10%    -0.2854      KARA2                                  2ahbut_c + h_c + nadph_c <=> 23dhmp_c + nadp_c
#   0.00%  -0.002347   MECDPDH5                  2mecdp_c + 2.0 flxr_c + h_c --> 2.0 flxso_c + h2mb4p_c + h2o_c
#   0.00%  -0.002347      MEPCT                                       2me4p_c + ctp_c + h_c --> 4c2me_c + ppi_c
#   0.01%   -0.01704  MG2t3_2pp                                             2.0 h_c + mg2_p <=> 2.0 h_p + mg2_c
#   0.00% -0.0002397      MOCOS                  2.0 h_c + mobd_c + mptamp_c --> amp_c + cu2_c + h2o_c + moco_c
#   0.00% -0.0002397      MPTAT                                        atp_c + h_c + mpt_c --> mptamp_c + ppi_c
#   0.00% -0.0004794      MPTSS                                   atp_c + h_c + moadcoo_c --> moadamp_c + ppi_c
#   0.11%    -0.3033     MTHFR2                                  2.0 h_c + mlthf_c + nadh_c --> 5mthf_c + nad_c
#  43.14%     -124.1   NADH16pp                            4.0 h_c + nadh_c + q8_c --> 3.0 h_p + nad_c + q8h2_c
#   0.00%  -0.002238      NNATr                                       atp_c + h_c + nicrnt_c <=> dnad_c + ppi_c
#   0.00%  -0.004476      NNDPR                          2.0 h_c + prpp_c + quln_c --> co2_c + nicrnt_c + ppi_c
#   0.00% -1.965E-06   OGMEACPR                                h_c + nadph_c + ogmeACP_c --> hgmeACP_c + nadp_c
#   0.00% -1.965E-06   OGMEACPS                       h_c + malACP_c + malcoame_c --> co2_c + coa_c + ogmeACP_c
#   0.15%    -0.4426      OMCDC                                               3c4mop_c + h_c --> 4mop_c + co2_c
#   0.11%     -0.325      OMPDC                                                h_c + orot5p_c --> co2_c + ump_c
#   0.00% -0.0002191     OPHBDC                                                3ophb_c + h_c --> 2oph_c + co2_c
#   0.00% -1.965E-06   OPMEACPR                                h_c + nadph_c + opmeACP_c --> hpmeACP_c + nadp_c
#   0.00% -1.965E-06   OPMEACPS                         gmeACP_c + h_c + malACP_c --> ACP_c + co2_c + opmeACP_c
#   0.15%    -0.4343       P5CR                              1pyr5c_c + 2.0 h_c + nadph_c --> nadp_c + pro__L_c
#   0.00% -0.0005658      PPCDC                                              4ppcys_c + h_c --> co2_c + pan4p_c
#   0.06%     -0.182      PPNDH                                        h_c + pphn_c --> co2_c + h2o_c + phpyr_c
#   0.02%   -0.06269     PSD160                                               h_c + ps160_c --> co2_c + pe160_c
#   0.03%   -0.07389     PSD161                                               h_c + ps161_c --> co2_c + pe161_c
#   0.00% -0.0005658     PTPATi                                       atp_c + h_c + pan4p_c --> dpcoa_c + ppi_c
#   0.02%   -0.05141    RNTR1c2                   atp_c + 2.0 flxr_c + 2.0 h_c --> datp_c + 2.0 flxso_c + h2o_c
#   0.02%   -0.05308    RNTR2c2                   2.0 flxr_c + gtp_c + 2.0 h_c --> dgtp_c + 2.0 flxso_c + h2o_c
#   0.02%   -0.05308    RNTR3c2                   ctp_c + 2.0 flxr_c + 2.0 h_c --> dctp_c + 2.0 flxso_c + h2o_c
#   0.02%   -0.05141    RNTR4c2                   2.0 flxr_c + 2.0 h_c + utp_c --> dutp_c + 2.0 flxso_c + h2o_c
#   0.13%    -0.3744     SHK3Dr                                      3dhsk_c + h_c + nadph_c <=> nadp_c + skm_c
#   0.42%     -1.218       SULR                5.0 h_c + 3.0 nadph_c + so3_c --> 3.0 h2o_c + h2s_c + 3.0 nadp_c
#   0.00%  -0.005113   THRt2rpp                                               h_p + thr__L_p <=> h_c + thr__L_c
#   0.00% -0.0002191    THZPSN3 atp_c + dhgly_c + dxyl5p_c + h_c + iscssh_c + nadph_c --> 4mpetz_c + amp_c +...
#   0.00% -0.0002191      TMPPP                                   2mahmp_c + 4mpetz_c + h_c --> ppi_c + thmmp_c
#   0.08%    -0.2435       TRDR                                    h_c + nadph_c + trdox_c --> nadp_c + trdrd_c
#   0.03%   -0.09282      UAGDP                                    acgam1p_c + h_c + utp_c --> ppi_c + uacgam_c
#   0.01%    -0.0273      UAPGR                                     h_c + nadph_c + uaccg_c --> nadp_c + uamr_c
#   0.00% -0.0008763     UPPDC1                                      4.0 h_c + uppg3_c --> 4.0 co2_c + cpppg3_c
# 5apru_c
# =======
# Formula: C9H13N4O9P
#
# Producing Reactions
# -------------------
# Percent      Flux Reaction                                  Definition
# 100.00% 0.0004381  DHPPDA2 25drapp_c + h2o_c + h_c --> 5apru_c + nh4_c
#
# Consuming Reactions
# -------------------
# Percent       Flux Reaction                                    Definition
# 100.00% -0.0004381   APRAUR 5apru_c + h_c + nadph_c --> 5aprbu_c + nadp_c
# nh4_c
# =====
# Formula: H4N
#
# Producing Reactions
# -------------------
# Percent      Flux Reaction                                                 Definition
#   1.36%    0.1512    CYSTL            cyst__L_c + h2o_c --> hcys__L_c + nh4_c + pyr_c
#   0.00% 0.0004381  DHPPDA2                25drapp_c + h2o_c + h_c --> 5apru_c + nh4_c
#   0.48%   0.05364    GLYCL gly_c + nad_c + thf_c --> co2_c + mlthf_c + nadh_c + nh4_c
#   0.02%  0.001753     HMBS                h2o_c + 4.0 ppbng_c --> hmbil_c + 4.0 nh4_c
#  95.56%     10.61   NH4tpp                                            nh4_p <=> nh4_c
#   2.57%    0.2854   THRD_L                               thr__L_c --> 2obut_c + nh4_c
#
# Consuming Reactions
# -------------------
# Percent      Flux                       Reaction                                                                      Definition
#   2.13%   -0.2368                          ASNS2                     asp__L_c + atp_c + nh4_c --> amp_c + asn__L_c + h_c + ppi_c
#   0.12%  -0.01278 BIOMASS_Ec_iJO1366_core_53p95M 0.000223 10fthf_c + 2.6e-05 2fe2s_c + 0.000223 2ohph_c + 0.00026 4fe4s_c + 0...
#   5.54%   -0.6155                          CBMKr                               atp_c + co2_c + nh4_c <=> adp_c + cbp_c + 2.0 h_c
#  16.02%    -1.779                           GLNS                      atp_c + glu__L_c + nh4_c --> adp_c + gln__L_c + h_c + pi_c
#  75.66%    -8.401                          GLUDy                     glu__L_c + h2o_c + nadp_c <=> akg_c + h_c + nadph_c + nh4_c
#   0.02% -0.002238                          NADS1                          atp_c + dnad_c + nh4_c --> amp_c + h_c + nad_c + ppi_c
#   0.50%  -0.05584                         TRPAS2                                   h2o_c + trp__L_c <=> indole_c + nh4_c + pyr_c

# %%
@dataclass
class Descriptor:
    name: str
    aka: Optional[List[str]] = None
    crossref: Optional[List[str]] = None


@dataclass
class Molecule:
    id: str
    descriptor: Descriptor
    formula: Optional[str] = None
    charge: Optional[int] = None
    molecular_weight: Optional[float] = None
    localization: Optional[str] = None
    formation_delta_g: Optional[float] = None


@dataclass
class Reaction:
    id: str
    descriptor: Descriptor
    stoichiometry: Mapping[str, float]
    catalyst: str
    reversible: bool = True
    standard_delta_g: Optional[float] = None

        
def extract_descriptor(bigg_obj):
    fields = {"name": bigg_obj.name}
    if bigg_obj.annotation:
        fields["crossref"] = [f"[{k}]:[{v}]" for k, v in bigg_obj.annotation.items()]
    
    return Descriptor(**fields)


def bigg_to_molecule(bigg_molecule):
    return Molecule(
        id = bigg_molecule.id,
        descriptor = extract_descriptor(bigg_molecule),
        formula = bigg_molecule.formula,
        charge = bigg_molecule.charge,
        molecular_weight = bigg_molecule.formula_weight,
        localization = bigg_molecule.compartment,
    )


def bigg_to_reaction(bigg_reaction):
    return Reaction(
        id = bigg_reaction.id,
        descriptor = extract_descriptor(bigg_reaction),
        stoichiometry = {m.id: count for m, count in bigg_reaction.metabolites.items()},
        catalyst = bigg_reaction.gene_reaction_rule,
        reversible = bigg_reaction.reversibility,
    )

# %%
molecules = {}
for m in bigg_core.metabolites:
    molecule = bigg_to_molecule(m)
    molecules[molecule.id] = molecule
print(f"Imported {len(molecules)} molecules")
# Out:
# Imported 1805 molecules
# /home/fdrusso/.pyenv/versions/3.8.5/envs/msmtk/lib/python3.8/site-packages/cobra/core/metabolite.py:135: UserWarning: The element 'R' does not appear in the periodic table
#   warn("The element %s does not appear in the periodic table" % e)
# /home/fdrusso/.pyenv/versions/3.8.5/envs/msmtk/lib/python3.8/site-packages/cobra/core/metabolite.py:135: UserWarning: The element 'X' does not appear in the periodic table
#   warn("The element %s does not appear in the periodic table" % e)

# %%
reactions = {}
exchanges = set()
biomass = {}

for r in bigg_core.reactions:
    if len(r.metabolites) == 1:
        exchanges.add(next(iter(r.metabolites)).id)
    elif r.id.startswith("BIOMASS"):
        biomass[r.id] = {m.id: count for m, count in r.metabolites.items()}
    else:
        reaction = bigg_to_reaction(r)
        reactions[reaction.id] = reaction
        
print(f"Imported {len(reactions)} reactions,"
      f" {len(exchanges)} exchanges,"
      f" {len(biomass)} biomass objectives")
# Out:
# Imported 2251 reactions, 330 exchanges, 2 biomass objectives

# %%
biomass.keys()
# Out:
# dict_keys(['BIOMASS_Ec_iJO1366_WT_53p95M', 'BIOMASS_Ec_iJO1366_core_53p95M'])

# %%
kb = pymongo.MongoClient("mongodb://127.0.0.1:27017").kb

# %%
def put_molecules(molecules, batch_size=100):
    i = 0
    written = 0
    while i < len(molecules):
        batch = []
        for molecule in molecules[i:i+batch_size]:
            batch.append(asdict(molecule))
        print(f"{written} molecules written, writing {len(batch)}...")
        result = kb.molecules.insert_many(batch, ordered=False)
        written += len(result.inserted_ids)
        i += batch_size
    print(f"{written} molecules total")

def put_reactions(reactions, batch_size=100):
    i = 0
    written = 0
    while i < len(reactions):
        batch = []
        for reaction in reactions[i:i+batch_size]:
            batch.append(asdict(reaction))
        print(f"{written} reactions written, writing {len(batch)}...")
        result = kb.reactions.insert_many(batch, ordered=False)
        written += len(result.inserted_ids)
        i += batch_size
    print(f"{written} reactions total")

# %%
put_reactions(list(reactions.values()))
# Out:
# 0 reactions written, writing 100...
# 100 reactions written, writing 100...
# 200 reactions written, writing 100...
# 300 reactions written, writing 100...
# 400 reactions written, writing 100...
# 500 reactions written, writing 100...
# 600 reactions written, writing 100...
# 700 reactions written, writing 100...
# 800 reactions written, writing 100...
# 900 reactions written, writing 100...
# 1000 reactions written, writing 100...
# 1100 reactions written, writing 100...
# 1200 reactions written, writing 100...
# 1300 reactions written, writing 100...
# 1400 reactions written, writing 100...
# 1500 reactions written, writing 100...
# 1600 reactions written, writing 100...
# 1700 reactions written, writing 100...
# 1800 reactions written, writing 100...
# 1900 reactions written, writing 100...
# 2000 reactions written, writing 100...
# 2100 reactions written, writing 100...
# 2200 reactions written, writing 51...
# 2251 reactions total
